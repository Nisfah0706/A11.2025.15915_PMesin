# %% [markdown]
# <a href="https://colab.research.google.com/github/Nisfah0706/A11.2025.15915_PMesin/blob/main/Praktikum_Mesin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!@#!#!$")
print("test")
# Out:
# Hello World!@#!#!$
# test

# %%
print("Hello, Python!")
print("Nisfah")
print('Nisfah')
# Out:
# Hello, Python!
# Nisfah
# Nisfah

# %%
print()

print("Nama saya Rohimatun Nisfah\n bisa dipanggil Nisfah")
print("Nama saya Rohimatun Nisfah\t bisa dipanggil Nisfah")
# Out:
# Nama saya Rohimatun Nisfah
#  bisa dipanggil Nisfah
# Nama saya Rohimatun Nisfah	 bisa dipanggil Nisfah

# %%
print("nama saya \"Nisfah\"")
# Out:
# nama saya "Nisfah"

# %%
print("\"")
# Out:
# "

# %%
print("satu.","dua.","tiga.")
# Out:
# satu. dua. tiga.

# %%
print("Nama saya","Rohimatun", end=" ")
print("Nisfah")
# Out:
# Nama saya Rohimatun Nisfah

# %%
print("satu","dua","tiga", sep=", ")
# Out:
# satu, dua, tiga

# %%
#Clue
print("Programming","Essentials","in")
print("Python")
# Out:
# Programming Essentials in
# Python

# %%
#Programming***Essentials***in...PythonPython

print("Programming","Essentials","in", sep="***", end="...")
print("Python"*2)
# Out:
# Programming***Essentials***in...PythonPython

# %%
#clue

print("    *    "*2)
print("   * *   "*2)
print("  *   *  "*2)
print(" *     * "*2)
print("***   ***"*2)
print("  *   *  "*2)
print("  *   *  "*2)
print("  *****  "*2)
# Out:
#     *        *
#    * *      * *
#   *   *    *   *
#  *     *  *     *
# ***   ******   ***
#   *   *    *   *
#   *   *    *   *
#   *****    *****

# %%
print("    *\n   * *\n  *   *\n *     *\n***   ***\n  *   *\n  *   *\n  *****\n"*2)
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
