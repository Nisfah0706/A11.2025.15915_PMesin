# %% [markdown]
# <a href="https://colab.research.google.com/github/Nisfah0706/A11.2025.15915_PMesin/blob/main/pseudoLabelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5e9ddd72-ddd0-4e6b-a494-b7130c2af4ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e9ddd72-ddd0-4e6b-a494-b7130c2af4ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-04a0cd82-583f-401e-964d-b8fd7f0865f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04a0cd82-583f-401e-964d-b8fd7f0865f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'Train.csv',
#  'Train (1).csv',
#  'Test (1).csv',
#  'Test.csv',
#  'sample_data']

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
# handle missing values (modern way)
train['Item_Weight'] = train['Item_Weight'].fillna(train['Item_Weight'].mean())
test['Item_Weight'] = test['Item_Weight'].fillna(test['Item_Weight'].mean())

train['Outlet_Size'] = train['Outlet_Size'].fillna('Small')
test['Outlet_Size'] = test['Outlet_Size'].fillna('Small')

# combine data (REPLACE append)
combi = pd.concat([train, test], axis=0, ignore_index=True)
